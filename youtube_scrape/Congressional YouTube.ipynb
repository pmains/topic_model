# %%
import pandas as pd
import numpy as np

df = pd.read_excel("youtube.xlsx")
df.head()
# Out:
#   last_name first_name nickname           state       party district  \
# 0      Alma      Adams      NaN  North Carolina  DEMOCRATIC       12
# 1    Robert   Aderholt      NaN         Alabama  REPUBLICAN        4
# 2      Pete    Aguilar      NaN      California  DEMOCRATIC       33
# 3      Mark     Alford      NaN        Missouri  REPUBLICAN        4
# 4      Rick      Allen      NaN         Georgia  REPUBLICAN       12
#
#                                     official_channel  \
# 0         https://www.youtube.com/@rep.almaadams1275
# 1            https://www.youtube.com/@RobertAderholt
# 2       https://www.youtube.com/@rep.peteaguilar4281
# 3                 https://www.youtube.com/@RepAlford
# 4  https://www.youtube.com/@congressmanrickallen8082
#
#                                     campaign_channel chamber
# 0      https://www.youtube.com/@AlmaAdamsforCongress   House
# 1                                                NaN   House
# ...

# %%
channel_set = set(df.official_channel.dropna()).union(set(df.official_channel.dropna()))
# Out:
# {'https://www.youtube.com/@Ann4Congress',
#  'https://www.youtube.com/@BLuetkemeyer',
#  'https://www.youtube.com/@BMcCollum04',
#  'https://www.youtube.com/@BrettGuthrie',
#  'https://www.youtube.com/@CohenForCongress2010',
#  'https://www.youtube.com/@CongMikeSimpson',
#  'https://www.youtube.com/@CongressmanBobLatta',
#  'https://www.youtube.com/@CongressmanBradShermanCA',
#  'https://www.youtube.com/@CongressmanBuddyCarter',
#  'https://www.youtube.com/@CongressmanClayHiggins',
#  'https://www.youtube.com/@CongressmanDanKildee',
#  'https://www.youtube.com/@CongressmanGT',
#  'https://www.youtube.com/@CongressmanHiggins',
#  'https://www.youtube.com/@CongressmanJeffVanDrew',
#  'https://www.youtube.com/@CongressmanJimMcGovern',
#  'https://www.youtube.com/@CongressmanJohnSarbanes',
#  'https://www.youtube.com/@CongressmanLamborn',
#  'https://www.youtube.com/@CongressmanLanceGooden',
#  'https://www.youtube.com/@CongressmanLarsen',
# ...
